# %%
import pandas as pd
df = pd.read_csv("../Data/f1_sponsors.csv")
df.head()
# Out:
#        Team   Sponsor      Category Region Visability Value_Level
# 0  Red Bull    Oracle          Tech    USA        Car        High
# 1  Red Bull  Heineken     Beverages     EU       Suit      Medium
# 2  Red Bull    Mobil1        Energy    USA        Car      Medium
# 3  Red Bull      Visa       Finance    USA        Car        High
# 4  Red Bull  TAGHeuer  Luxury Goods     EU        Car        High

# %%
df.groupby("Category").size()
# Out:
# Category
# Automotive        3
# Beverages         1
# Clothing          2
# Consumer Goods    2
# Energy            3
# Finance           3
# Luxury Goods      3
# Tech              3
# dtype: int64

# %%
df.groupby("Category").size().reset_index()
# Out:
#          Category  0
# 0      Automotive  3
# 1       Beverages  1
# 2        Clothing  2
# 3  Consumer Goods  2
# 4          Energy  3
# 5         Finance  3
# 6    Luxury Goods  3
# 7            Tech  3

# %%
variable_name = category_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 variable_name = category_summary
#
# NameError: name 'category_summary' is not defined

# %%
category_summary = df.groupby("Category").size().reset_index()
category_summary.head()
category_summary.rename(columns={0: count}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 category_summary = df.groupby("Category").size().reset_index()
#       2 category_summary.head()
# ----> 3 category_summary.rename(columns={0: count}, inplace=True)
#
# NameError: name 'count' is not defined

# %%
category_summary = df.groupby("Category").size().reset_index()
category_summary.rename(columns={0: "Count"}, inplace=True)

# %%
category_summary = df.groupby("Category").size().reset_index()
category_summary.rename(columns={0: "Count"}, inplace=True)
category_summary.head()
# Out:
#          Category  Count
# 0      Automotive      3
# 1       Beverages      1
# 2        Clothing      2
# 3  Consumer Goods      2
# 4          Energy      3

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.bar(category_summary["Category"], category_summary["Count"], color="blue")
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Sponsor Categories")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
region_summary = df.groupby("Region").size().reset_index()
region_summary.rename(columns={0: "Count"}, inplace=True)
region_summary.head()
# Out:
#         Region  Count
# 0       Asia        1
# 1         Asis      1
# 2           EU     10
# 3  Middle East      1
# 4          USA      7

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.bar(region_summary["Region"], region_summary["Count"], color="teal")
plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Sponsor Regions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
region_summary = df.groupby("Region").size().reset_index()
region_summary.rename(columns={0: "Count"}, inplace=True)
region_summary.head()
# Out:
#          Region  Count
# 0        Asia        1
# 1  Asia (Japan)      1
# 2  EU (Austria)      1
# 3   EU (France)      1
# 4  EU (Germany)      2

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.bar(region_summary["Region"], region_summary["Count"], color="teal")
plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Sponsor Regions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#        Team   Sponsor      Category            Region Visability Value_Level
# 0  Red Bull    Oracle          Tech               USA        Car        High
# 1  Red Bull  Heineken     Beverages  EU (Netherlands)       Suit      Medium
# 2  Red Bull    Mobil1        Energy               USA        Car      Medium
# 3  Red Bull      Visa       Finance               USA        Car        High
# 4  Red Bull  TAGHeuer  Luxury Goods  EU (Switzerland)        Car        High

# %%
df.head()
# Out:
#        Team   Sponsor      Category            Region Visability Value_Level
# 0  Red Bull    Oracle          Tech               USA        Car        High
# 1  Red Bull  Heineken     Beverages  EU (Netherlands)       Suit      Medium
# 2  Red Bull    Mobil1        Energy               USA        Car      Medium
# 3  Red Bull      Visa       Finance               USA        Car        High
# 4  Red Bull  TAGHeuer  Luxury Goods  EU (Switzerland)        Car        High

# %%
df["Region"].unique()
# Out:
# <ArrowStringArray>
# [             'USA', 'EU (Netherlands)', 'EU (Switzerland)',
#       'Middle East',     'Asia (Japan)',     'EU (Germany)',
#            'Asia  ',     'EU (Austria)',       'EU (Italy)',
#       'EU (France)']
# Length: 10, dtype: str

# %%
df = pd.read_csv("data/f1_sponsors.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = pd.read_csv("data/f1_sponsors.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
# ...

# %%
value_summary = df.groupby("Value_Level").size().reset_index()
value_summary.rename(columns={0: "Count"}, inplace=True)
value_summary.head()
# Out:
#   Value_Level  Count
# 0        High      9
# 1         Low      2
# 2      Medium      9

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.bar(region_summary["Value Level"], region_summary["Count"], color="lilac")
plt.xlabel("Value Level")
plt.ylabel("Count")
plt.title("Sponsor Value Level")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.bar(value_summary["Value_Level"], value_summary["Count"], color="darkorange")
plt.xlabel("Value Level")
plt.ylabel("Count")
plt.title("Sponsor Value Levels")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
